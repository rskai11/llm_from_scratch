# %%
with open ("C:\\Users\\rouna\\Desktop\\Development\\llm_from_scratch\\Data\\the-verdict.txt", "r") as file:
    raw_text = file.read()

# %%
import tiktoken

# %%
tokenizer = tiktoken.get_encoding("gpt2")

# %%
token_ids = tokenizer.encode(raw_text)
print(f"Total number of tokens: {len(token_ids)}")
# Out:
# Total number of tokens: 5145

# %%
context_size = 4

x=token_ids[:context_size]
y=token_ids[1:context_size+1]


print("Input token ids: ", x)
print("Target token ids:", y)
# Out:
# Input token ids:  [40, 367, 2885, 1464]
# Target token ids: [367, 2885, 1464, 1807]

# %%
for i in range(1,context_size+1):
    context=token_ids[:i]
    desired=token_ids[i]
    print(context, "---->", desired)
# Out:
# [40] ----> 367
# [40, 367] ----> 2885
# [40, 367, 2885] ----> 1464
# [40, 367, 2885, 1464] ----> 1807

# %%
for i in range(1,context_size+1):
    context=token_ids[:i]
    desired=token_ids[i]
    print(context, "---->", desired)
# Out:
# [40] ----> 367
# [40, 367] ----> 2885
# [40, 367, 2885] ----> 1464
# [40, 367, 2885, 1464] ----> 1807

# %%
for i in range(1, context_size + 1):
    context = token_ids[:i]
    desired = token_ids[i]
    context_text = tokenizer.decode(context)
    desired_text = tokenizer.decode([desired])
    print(f"{context} ({context_text!r}) ---> {desired} ({desired_text!r})")
# Out:
# [40] ('I') ---> 367 (' H')
# [40, 367] ('I H') ---> 2885 ('AD')
# [40, 367, 2885] ('I HAD') ---> 1464 (' always')
# [40, 367, 2885, 1464] ('I HAD always') ---> 1807 (' thought')

# %% [markdown]
# # Data Loader Using PyTorch

# %%
from torch.utils.data import DataLoader, Dataset
import torch

# %%
class GPTDaatasetV1 (Dataset):
    
    def __init__(self, txt, tokenizer, max_length,stride):
        self.tokenizer = tokenizer
        self.max_length = max_length
        self.stride = stride
        self.token_ids = tokenizer.encode(txt,allowed_special={"<|endoftext|>"})
        
        self.inputs = []
        self.targets = []
        
        for i in range(0, len(self.token_ids) - max_length, stride):
            input_chunks = self.token_ids[i:i + max_length]
            target_chunks = self.token_ids[i + 1:i + max_length + 1]
            self.inputs.append(torch.tensor(input_chunks))
            self.targets.append(torch.tensor(target_chunks))

    def __len__(self):
        return len(self.inputs)
    
    def __getitem__(self, idx):
        return self.inputs[idx], self.targets[idx]

# %%
def create_dataloader_V1 (txt, max_length=256, stride=128, batch_size=4,shuffle=True,drop_last=True,num_workers=0):

    tokenizer = tiktoken.get_encoding("gpt2")

    dataset = GPTDaatasetV1(txt, tokenizer, max_length, stride)

    dataloader= DataLoader(dataset, batch_size=batch_size, shuffle=shuffle, drop_last=drop_last,num_workers=num_workers)

    return dataloader

# %%
raw_text
# Out:
# 'I HAD always thought Jack Gisburn rather a cheap genius--though a good fellow enough--so it was no great surprise to me to hear that, in the height of his glory, he had dropped his painting, married a rich widow, and established himself in a villa on the Riviera. (Though I rather thought it would have been Rome or Florence.)\n\n"The height of his glory"--that was what the women called it. I can hear Mrs. Gideon Thwing--his last Chicago sitter--deploring his unaccountable abdication. "Of course it\'s going to send the value of my picture \'way up; but I don\'t think of that, Mr. Rickham--the loss to Arrt is all I think of." The word, on Mrs. Thwing\'s lips, multiplied its _rs_ as though they were reflected in an endless vista of mirrors. And it was not only the Mrs. Thwings who mourned. Had not the exquisite Hermia Croft, at the last Grafton Gallery show, stopped me before Gisburn\'s "Moon-dancers" to say, with tears in her eyes: "We shall not look upon its like again"?\n\nWell!--even through the prism of Hermia\'s tears I felt able to face the fact with equanimity. Poor Jack Gisburn! The women had made him--it was fitting that they should mourn him. Among his own sex fewer regrets were heard, and in his own trade hardly a murmur. Professional jealousy? Perhaps. If it were, the honour of the craft was vindicated by little Claude Nutley, who, in all good faith, brought out in the Burlington a very handsome "obituary" on Jack--one of those showy articles stocked with random technicalities that I have heard (I won\'t say by whom) compared to Gisburn\'s painting. And so--his resolve being apparently irrevocable--the discussion gradually died out, and, as Mrs. Thwing had predicted, the price of "Gisburns" went up.\n\nIt was not till three years later that, in the course of a few weeks\' idling on the Riviera, it suddenly occurred to me to wonder why Gisburn had given up his painting. On reflection, it really was a tempting problem. To accuse his wife would have been too easy--his fair sitters had been denied the solace of saying that Mrs. Gisburn had "dragged him down." For Mrs. Gisburn--as such--had not existed till nearly a year after Jack\'s resolve had been taken. It might be that he had married her--since he liked his ease--because he didn\'t want to go on painting; but it would have been hard to prove that he had given up his painting because he had married her.\n\nOf course, if she had not dragged him down, she had equally, as Miss Croft contended, failed to "lift him up"--she had not led him back to the easel. To put the brush into his hand again--what a vocation for a wife! But Mrs. Gisburn appeared to have disdained it--and I felt it might be interesting to find out why.\n\nThe desultory life of the Riviera lends itself to such purely academic speculations; and having, on my way to Monte Carlo, caught a glimpse of Jack\'s balustraded terraces between the pines, I had myself borne thither the next day.\n\nI found the couple at tea beneath their palm-trees; and Mrs. Gisburn\'s welcome was so genial that, in the ensuing weeks, I claimed it frequently. It was not that my hostess was "interesting": on that point I could have given Miss Croft the fullest reassurance. It was just because she was _not_ interesting--if I may be pardoned the bull--that I found her so. For Jack, all his life, had been surrounded by interesting women: they had fostered his art, it had been reared in the hot-house of their adulation. And it was therefore instructive to note what effect the "deadening atmosphere of mediocrity" (I quote Miss Croft) was having on him.\n\nI have mentioned that Mrs. Gisburn was rich; and it was immediately perceptible that her husband was extracting from this circumstance a delicate but substantial satisfaction. It is, as a rule, the people who scorn money who get most out of it; and Jack\'s elegant disdain of his wife\'s big balance enabled him, with an appearance of perfect good-breeding, to transmute it into objects of  ...

# %%
dataloader=create_dataloader_V1(raw_text, batch_size=1,max_length=4,stride=1,shuffle=False)

# %%
data_iter = iter(dataloader)
first_batch = next(data_iter)

# %%
print("Input batch:", first_batch)
# Out:
# Input batch: [tensor([[  40,  367, 2885, 1464]]), tensor([[ 367, 2885, 1464, 1807]])]

# %%
dataloader.dataset.inputs[1], dataloader.dataset.targets[0]
# Out:
# (tensor([ 367, 2885, 1464, 1807]), tensor([ 367, 2885, 1464, 1807]))

# %%
# # ...existing code...
# import torch
# # show full tensors instead of truncating
# try:
#     torch.set_printoptions(profile="full")
# except Exception:
#     torch.set_printoptions(threshold=10**6)

# # ensure dataloader was created with drop_last=False if you want last partial batch:
# # dataloader = create_dataloader_V1(raw_text, batch_size=1, max_length=4, stride=1, shuffle=False, drop_last=False)

# for batch_idx, (inputs, targets) in enumerate(dataloader):
#     print(f"Batch {batch_idx}: inputs.shape={inputs.shape}, targets.shape={targets.shape}, dtype={inputs.dtype}")
#     # inputs, targets are tensors of shape (batch_size, seq_len)
#     for sample_idx in range(inputs.size(0)):
#         inp_ids = inputs[sample_idx].tolist()
#         tgt_ids = targets[sample_idx].tolist()
#         inp_text = tokenizer.decode(inp_ids)
#         tgt_text = tokenizer.decode(tgt_ids)
#         print(f"  Sample {sample_idx}:")
#         print(f"    input ids : {inp_ids}")
#         print(f"    target ids: {tgt_ids}")
#         print(f"    input text: {inp_text!r}")
#         print(f"    target text: {tgt_text!r}")
#     print("-" * 80)
# Out:
# Batch 0: inputs.shape=torch.Size([1, 4]), targets.shape=torch.Size([1, 4]), dtype=torch.int64
#   Sample 0:
#     input ids : [40, 367, 2885, 1464]
#     target ids: [367, 2885, 1464, 1807]
#     input text: 'I HAD always'
#     target text: ' HAD always thought'
# --------------------------------------------------------------------------------
# Batch 1: inputs.shape=torch.Size([1, 4]), targets.shape=torch.Size([1, 4]), dtype=torch.int64
#   Sample 0:
#     input ids : [367, 2885, 1464, 1807]
#     target ids: [2885, 1464, 1807, 3619]
#     input text: ' HAD always thought'
#     target text: 'AD always thought Jack'
# --------------------------------------------------------------------------------
# Batch 2: inputs.shape=torch.Size([1, 4]), targets.shape=torch.Size([1, 4]), dtype=torch.int64
#   Sample 0:
#     input ids : [2885, 1464, 1807, 3619]
#     target ids: [1464, 1807, 3619, 402]
#     input text: 'AD always thought Jack'
#     target text: ' always thought Jack G'
# --------------------------------------------------------------------------------
# Batch 3: inputs.shape=torch.Size([1, 4]), targets.shape=torch.Size([1, 4]), dtype=torch.int64
#   Sample 0:
#     input ids : [1464, 1807, 3619, 402]
#     target ids: [1807, 3619, 402, 271]
#     input text: ' always thought Jack G'
#     target text: ' thought Jack Gis'
# --------------------------------------------------------------------------------
# Batch 4: inputs.shape=torch.Size([1, 4]), targets.shape=torch.Size([1, 4]), dtype=torch.int64
#   Sample 0:
#     input ids : [1807, 3619, 402, 271]
#     target ids: [3619, 402, 271, 10899]
#     input text: ' thought Jack Gis'
#     target text: ' Jack Gisburn'
# --------------------------------------------------------------------------------
# Batch 5: inputs.shape=torch.Size([1, 4]), targets.shape=torch.Size([1, 4]), dtype=torch.int64
#   Sample 0:
#     input ids : [3619, 402, 271, 10899]
#     target ids: [402, 271, 10899, 2138]
#     input text: ' Jack Gisburn'
#     target text: ' Gisburn rather'
# --------------------------------------------------------------------------------
# Batch 6: inputs.shape=torch.Size([1, 4]), targets.shape=torch.Size([1, 4]), dtype=torch.int64
#   Sample 0:
#     input ids : [402, 271, 10899, 2138]
#     target ids: [271, 10899, 2138, 257]
#     input text: ' Gisburn rather'
#     target text: 'isburn rather a'
# --------------------------------------------------------------------------------
# Batch 7: inputs.shape=torch.Size([1, 4]), targets.shape=torch.Size([1, 4]), dtype=torch.int64
#   Sample 0:
#     input ids : [271, 10899, 2138, 257]
#     target ids: [10899, 2138, 257, 7026]
#     input text: 'isburn rather a'
#     target text: 'burn rather a cheap'
# --------------------------------------------------------------------------------
# Batch 8: inputs.shape=torch.Size([1, 4]), targets.shape=torch.Size([1, 4]), dtype=torch.int64
#   Sample 0:
#     input ids : [10899, 2138, 257, 7026]
#     target ids: [2138, 257, 7026, 15632]
#     input text: 'burn rather a cheap'
#     target text: ' rather a cheap genius'
# --------------------------------------------------------------------------------
# Batch 9: inputs.shape=torch.Size([1, 4]), targets.shape=torch.Size([1, 4]), dtype=torch.int64
#   Sample 0:
#     input ids : [2138, 257, 7026, 15632]
#     target ids: [257, 7026, 15632, 438]
#     input text: ' rather a cheap genius'
#     target text: ' a cheap genius--'
# --------------------------------------------------------------------------------
# Batch 10: inputs.shape=torch.Size([1, 4]), targets.shape=torch.Size([1, 4]), dtype=torch.int64
#   Sample 0:
#     input ids : [257, 7026, 15632, 438]
#     target ids: [7026, 15632, 438, 2016]
#     input text: ' a cheap genius--'
#     target text: ' cheap genius--though'
# --------------------------------------------------------------------------------
# Batch 11: inputs.shape=torch.Size([1, 4]), targets.shape=torch.Size([1, 4]), dtype=torch.int64
#   Sample 0:
#     input ids : [7026, 15632, 438, 2016]
#     target ids: [15632, 438, 2016, 257]
#     input text: ' cheap genius--though'
#     target text: ' genius--though a'
# --------------------------------------------------------------------------------
# Batch 12: inputs.shape=torch.Size([1, 4]), targets.shape=torch.Size([1, 4]), dtype=torch.int64
#   Sample 0:
#     input ids : [15632, 438, 2016, 257]
#     target ids: [438, 2016, 257, 922]
#     input text: ' genius--though a'
#     target text: '--though a good'
# --------------------------------------------------------------------------------
# Batch 13: inputs.shape=torch.Size([1, 4]), targets.shape=torch.Size([1, 4]), dtype=torch.int64
#   Sample 0:
#     input ids : [438, 2016, 257, 922]
#     target ids: [2016, 257, 922, 5891]
#     input text: '--though a good'
#     target text: 'though a good fellow'
# --------------------------------------------------------------------------------
# Batch 14: inputs.shape=torch.Size([1, 4]), targets.shape=torch.Size([1, 4]), dtype=torch.int64
#   Sample 0:
#     input ids : [2016, 257, 922, 5891]
#     target ids: [257, 922, 5891, 1576]
#     input text: 'though a good fellow'
#     target text: ' a good fellow enough'
# --------------------------------------------------------------------------------
# Batch 15: inputs.shape=torch.Size([1, 4]), targets.shape=torch.Size([1, 4]), dtype=torch.int64
#   Sample 0:
#     input ids : [257, 922, 5891, 1576]
#     target ids: [922, 5891, 1576, 438]
#     input text: ' a good fellow enough'
#     target text: ' good fellow enough--'
# --------------------------------------------------------------------------------
# Batch 16: inputs.shape=torch.Size([1, 4]), targets.shape=torch.Size([1, 4]), dtype=torch.int64
#   Sample 0:
#     input ids : [922, 5891, 1576, 438]
#     target ids: [5891, 1576, 438, 568]
#     input text: ' good fellow enough--'
#     target text: ' fellow enough--so'
# --------------------------------------------------------------------------------
# Batch 17: inputs.shape=torch.Size([1, 4]), targets.shape=torch.Size([1, 4]), dtype=torch.int64
#   Sample 0:
#     input ids : [5891, 1576, 438, 568]
#     target ids: [1576, 438, 568, 340]
#     input text: ' fellow enough--so'
#     target text: ' enough--so it'
# --------------------------------------------------------------------------------
# Batch 18: inputs.shape=torch.Size([1, 4]), targets.shape=torch.Size([1, 4]), dtype=torch.int64
#   Sample 0:
#     input ids : [1576, 438, 568, 340]
#     target ids: [438, 568, 340, 373]
#     input text: ' enough--so it'
#     target text: '--so it was'
# --------------------------------------------------------------------------------
# Batch 19: inputs.shape=torch.Size([1, 4]), targets.shape=torch.Size([1, 4]), dtype=torch.int64
#   Sample 0:
#     input ids : [438, 568, 340, 373]
#     target ids: [568, 340, 373, 645]
#     input text: '--so it was'
#     target text: 'so it was no'
# --------------------------------------------------------------------------------
# Batch 20: inputs.shape=torch.Size([1, 4]), targets.shape=torch.Size([1, 4]), dtype=torch.int64
#   Sample 0:
#     input ids : [568, 340, 373, 645]
#     target ids: [340, 373, 645, 1049]
#     input text: 'so it was no'
#     target text: ' it was no great'
# --------------------------------------------------------------------------------
# Batch 21: inputs.shape=torch.Size([1, 4]), targets.shape=torch.Size([1, 4]), dtype=torch.int64
#   Sample 0:
#     input ids : [340, 373, 645, 1049]
#     target ids: [373, 645, 1049, 5975]
#     input text: ' it was no great'
#     target text: ' was no great surprise'
# --------------------------------------------------------------------------------
# Batch 22: inputs.shape=torch.Size([1, 4]), targets.shape=torch.Size([1, 4]), dtype=torch.int64
#   Sample 0:
#     input ids : [373, 645, 1049, 5975]
#     target ids: [645, 1049, 5975, 284]
#     input text: ' was no great surprise'
#     target text: ' no great surprise to'
# --------------------------------------------------------------------------------
# Batch 23: inputs.shape=torch.Size([1, 4]), targets.shape=torch.Size([1, 4]), dtype=torch.int64
#   Sample 0:
#     input ids : [645, 1049, 5975, 284]
#     target ids: [1049, 5975, 284, 502]
#     input text: ' no great surprise to'
#     target text: ' great surprise to me'
# --------------------------------------------------------------------------------
# Batch 24: inputs.shape=torch.Size([1, 4]), targets.shape=torch.Size([1, 4]), dtype=torch.int64
#   Sample 0:
#     input ids : [1049, 5975, 284, 502]
#     target ids: [5975, 284, 502, 284]
#     input text: ' great surprise to me'
#     target text: ' surprise to me to'
# --------------------------------------------------------------------------------
# Batch 25: inputs.shape=torch.Size([1, 4]), targets.shape=torch.Size([1, 4]), dtype=torch.int64
#   Sample 0:
#     input ids : [5975, 284, 502, 284]
#     target ids: [284, 502, 284, 3285]
#     input text: ' surprise to me to'
#     target text: ' to me to hear'
# --------------------------------------------------------------------------------
# Batch 26: inputs.shape=torch.Size([1, 4]), targets.shape=torch.Size([1, 4]), dtype=torch.int64
#   Sample 0:
#     input ids : [284, 502, 284, 3285]
#     target ids: [502, 284, 3285, 326]
#     input text: ' to me to hear'
#     target text: ' me to hear that'
# --------------------------------------------------------------------------------
# Batch 27: inputs.shape=torch.Size([1, 4]), targets.shape=torch.Size([1, 4]), dtype=torch.int64
#   Sample 0:
#     input ids : [502, 284, 3285, 326]
#     target ids: [284, 3285, 326, 11]
#     input text: ' me to hear that'
#     target text: ' to hear that,'
# --------------------------------------------------------------------------------
# Batch 28: inputs.shape=torch.Size([1, 4]), targets.shape=torch.Size([1, 4]), dtype=torch.int64
#   Sample 0:
#     input ids : [284, 3285, 326, 11]
#     target ids: [3285, 326, 11, 287]
#     input text: ' to hear that,'
#     target text: ' hear that, in'
# --------------------------------------------------------------------------------
# Batch 29: inputs.shape=torch.Size([1, 4]), targets.shape=torch.Size([1, 4]), dtype=torch.int64
#   Sample 0:
#     input ids : [3285, 326, 11, 287]
#     target ids: [326, 11, 287, 262]
#     input text: ' hear that, in'
#     target text: ' that, in the'
# --------------------------------------------------------------------------------
# Batch 30: inputs.shape=torch.Size([1, 4]), targets.shape=torch.Size([1, 4]), dtype=torch.int64
#   Sample 0:
#     input ids : [326, 11, 287, 262]
#     target ids: [11, 287, 262, 6001]
#     input text: ' that, in the'
#     target text: ', in the height'
# --------------------------------------------------------------------------------
# Batch 31: inputs.shape=torch.Size([1, 4]), targets.shape=torch.Size([1, 4]), dtype=torch.int64
#   Sample 0:
#     input ids : [11, 287, 262, 6001]
#     target ids: [287, 262, 6001, 286]
#     input text: ', in the height'
#     target text: ' in the height of'
# --------------------------------------------------------------------------------
# Batch 32: inputs.shape=torch.Size([1, 4]), targets.shape=torch.Size([1, 4]), dtype=torch.int64
#   Sample 0:
#     input ids : [287, 262, 6001, 286]
#     target ids: [262, 6001, 286, 465]
#     input text: ' in the height of'
#     target text: ' the height of his'
# --------------------------------------------------------------------------------
# Batch 33: inputs.shape=torch.Size([1, 4]), targets.shape=torch.Size([1, 4]), dtype=torch.int64
#   Sample 0:
#     input ids : [262, 6001, 286, 465]
#     target ids: [6001, 286, 465, 13476]
#     input text: ' the height of his'
#     target text: ' height of his glory'
# --------------------------------------------------------------------------------
# Batch 34: inputs.shape=torch.Size([1, 4]), targets.shape=torch.Size([1, 4]), dtype=torch.int64
#   Sample 0:
#     input ids : [6001, 286, 465, 13476]
#     target ids: [286, 465, 13476, 11]
#     input text: ' height of his glory'
#     target text: ' of his glory,'
# --------------------------------------------------------------------------------
# Batch 35: inputs.shape=torch.Size([1, 4]), targets.shape=torch.Size([1, 4]), dtype=torch.int64
#   Sample 0:
#     input ids : [286, 465, 13476, 11]
#     target ids: [465, 13476, 11, 339]
#     input text: ' of his glory,'
#     target text: ' his glory, he'
# --------------------------------------------------------------------------------
# Batch 36: inputs.shape=torch.Size([1, 4]), targets.shape=torch.Size([1, 4]), dtype=torch.int64
#   Sample 0:
#     input ids : [465, 13476, 11, 339]
#     target ids: [13476, 11, 339, 550]
#     input text: ' his glory, he'
#     target text: ' glory, he had'
# --------------------------------------------------------------------------------
# Batch 37: inputs.shape=torch.Size([1, 4]), targets.shape=torch.Size([1, 4]), dtype=torch.int64
#   Sample 0:
#     input ids : [13476, 11, 339, 550]
#     target ids: [11, 339, 550, 5710]
#     input text: ' glory, he had'
#     target text: ', he had dropped'
# --------------------------------------------------------------------------------
# Batch 38: inputs.shape=torch.Size([1, 4]), targets.shape=torch.Size([1, 4]), dtype=torch.int64
#   Sample 0:
#     input ids : [11, 339, 550, 5710]
#     target ids: [339, 550, 5710, 465]
#     input text: ', he had dropped'
#     target text: ' he had dropped his'
# --------------------------------------------------------------------------------
# Batch 39: inputs.shape=torch.Size([1, 4]), targets.shape=torch.Size([1, 4]), dtype=torch.int64
#   Sample 0:
#     input ids : [339, 550, 5710, 465]
#     target ids: [550, 5710, 465, 12036]
#     input text: ' he had dropped his'
#     target text: ' had dropped his painting'
# --------------------------------------------------------------------------------
# Batch 40: inputs.shape=torch.Size([1, 4]), targets.shape=torch.Size([1, 4]), dtype=torch.int64
#   Sample 0:
#     input ids : [550, 5710, 465, 12036]
#     target ids: [5710, 465, 12036, 11]
#     input text: ' had dropped his painting'
#     target text: ' dropped his painting,'
# --------------------------------------------------------------------------------
# Batch 41: inputs.shape=torch.Size([1, 4]), targets.shape=torch.Size([1, 4]), dtype=torch.int64
#   Sample 0:
#     input ids : [5710, 465, 12036, 11]
#     target ids: [465, 12036, 11, 6405]
#     input text: ' dropped his painting,'
#     target text: ' his painting, married'
# --------------------------------------------------------------------------------
# Batch 42: inputs.shape=torch.Size([1, 4]), targets.shape=torch.Size([1, 4]), dtype=torch.int64
#   Sample 0:
#     input ids : [465, 12036, 11, 6405]
#     target ids: [12036, 11, 6405, 257]
#     input text: ' his painting, married'
#     target text: ' painting, married a'
# --------------------------------------------------------------------------------
# Batch 43: inputs.shape=torch.Size([1, 4]), targets.shape=torch.Size([1, 4]), dtype=torch.int64
#   Sample 0:
#     input ids : [12036, 11, 6405, 257]
#     target ids: [11, 6405, 257, 5527]
#     input text: ' painting, married a'
#     target text: ', married a rich'
# --------------------------------------------------------------------------------
# Batch 44: inputs.shape=torch.Size([1, 4]), targets.shape=torch.Size([1, 4]), dtype=torch.int64
#   Sample 0:
#     input ids : [11, 6405, 257, 5527]
#     target ids: [6405, 257, 5527, 27075]
#     input text: ', married a rich'
#     target text: ' married a rich widow'
# --------------------------------------------------------------------------------
# Batch 45: inputs.shape=torch.Size([1, 4]), targets.shape=torch.Size([1, 4]), dtype=torch.int64
#   Sample 0:
#     input ids : [6405, 257, 5527, 27075]
#     target ids: [257, 5527, 27075, 11]
#     input text: ' married a rich widow'
#     target text: ' a rich widow,'
# --------------------------------------------------------------------------------
# Batch 46: inputs.shape=torch.Size([1, 4]), targets.shape=torch.Size([1, 4]), dtype=torch.int64
#   Sample 0:
#     input ids : [257, 5527, 27075, 11]
#     target ids: [5527, 27075, 11, 290]
#     input text: ' a rich widow,'
#     target text: ' rich widow, and'
# --------------------------------------------------------------------------------
# Batch 47: inputs.shape=torch.Size([1, 4]), targets.shape=torch.Size([1, 4]), dtype=torch.int64
#   Sample 0:
#     input ids : [5527, 27075, 11, 290]
#     target ids: [27075, 11, 290, 4920]
#     input text: ' rich widow, and'
#     target text: ' widow, and established'
# --------------------------------------------------------------------------------
# Batch 48: inputs.shape=torch.Size([1, 4]), targets.shape=torch.Size([1, 4]), dtype=torch.int64
#   Sample 0:
#     input ids : [27075, 11, 290, 4920]
#     target ids: [11, 290, 4920, 2241]
#     input text: ' widow, and established'
#     target text: ', and established himself'
# --------------------------------------------------------------------------------
# Batch 49: inputs.shape=torch.Size([1, 4]), targets.shape=torch.Size([1, 4]), dtype=torch.int64
#   Sample 0:
#     input ids : [11, 290, 4920, 2241]
#     target ids: [290, 4920, 2241, 287]
#     input text: ', and established himself'
#     target text: ' and established himself in'
# --------------------------------------------------------------------------------
# Batch 50: inputs.shape=torch.Size([1, 4]), targets.shape=torch.Size([1, 4]), dtype=torch.int64
#   Sample 0:
#     input ids : [290, 4920, 2241, 287]
#     target ids: [4920, 2241, 287, 257]
#     input text: ' and established himself in'
#     target text: ' established himself in a'
# --------------------------------------------------------------------------------
# Batch 51: inputs.shape=torch.Size([1, 4]), targets.shape=torch.Size([1, 4]), dtype=torch.int64
#   Sample 0:
#     input ids : [4920, 2241, 287, 257]
#     target ids: [2241, 287, 257, 4489]
#     input text: ' established himself in a'
#     target text: ' himself in a vill'
# --------------------------------------------------------------------------------
# Batch 52: inputs.shape=torch.Size([1, 4]), targets.shape=torch.Size([1, 4]), dtype=torch.int64
#   Sample 0:
#     input ids : [2241, 287, 257, 4489]
#     target ids: [287, 257, 4489, 64]
#     input text: ' himself in a vill'
#     target text: ' in a villa'
# --------------------------------------------------------------------------------
# Batch 53: inputs.shape=torch.Size([1, 4]), targets.shape=torch.Size([1, 4]), dtype=torch.int64
#   Sample 0:
#     input ids : [287, 257, 4489, 64]
#     target ids: [257, 4489, 64, 319]
#     input text: ' in a villa'
#     target text: ' a villa on'
# --------------------------------------------------------------------------------
# Batch 54: inputs.shape=torch.Size([1, 4]), targets.shape=torch.Size([1, 4]), dtype=torch.int64
#   Sample 0:
#     input ids : [257, 4489, 64, 319]
#     target ids: [4489, 64, 319, 262]
#     input text: ' a villa on'
#     target text: ' villa on the'
# --------------------------------------------------------------------------------
# Batch 55: inputs.shape=torch.Size([1, 4]), targets.shape=torch.Size([1, 4]), dtype=torch.int64
#   Sample 0:
#     input ids : [4489, 64, 319, 262]
#     target ids: [64, 319, 262, 34686]
#     input text: ' villa on the'
#     target text: 'a on the Riv'
# --------------------------------------------------------------------------------
# Batch 56: inputs.shape=torch.Size([1, 4]), targets.shape=torch.Size([1, 4]), dtype=torch.int64
#   Sample 0:
#     input ids : [64, 319, 262, 34686]
#     target ids: [319, 262, 34686, 41976]
#     input text: 'a on the Riv'
#     target text: ' on the Riviera'
# --------------------------------------------------------------------------------
# Batch 57: inputs.shape=torch.Size([1, 4]), targets.shape=torch.Size([1, 4]), dtype=torch.int64
#   Sample 0:
#     input ids : [319, 262, 34686, 41976]
#     target ids: [262, 34686, 41976, 13]
#     input text: ' on the Riviera'
#     target text: ' the Riviera.'
# --------------------------------------------------------------------------------
# Batch 58: inputs.shape=torch.Size([1, 4]), targets.shape=torch.Size([1, 4]), dtype=torch.int64
#   Sample 0:
#     input ids : [262, 34686, 41976, 13]
#     target ids: [34686, 41976, 13, 357]
#     input text: ' the Riviera.'
#     target text: ' Riviera. ('
# --------------------------------------------------------------------------------
# Batch 59: inputs.shape=torch.Size([1, 4]), targets.shape=torch.Size([1, 4]), dtype=torch.int64
#   Sample 0:
#     input ids : [34686, 41976, 13, 357]
#     target ids: [41976, 13, 357, 10915]
#     input text: ' Riviera. ('
#     target text: 'iera. (Though'
# --------------------------------------------------------------------------------
# Batch 60: inputs.shape=torch.Size([1, 4]), targets.shape=torch.Size([1, 4]), dtype=torch.int64
#   Sample 0:
#     input ids : [41976, 13, 357, 10915]
#     target ids: [13, 357, 10915, 314]
#     input text: 'iera. (Though'
#     target text: '. (Though I'
# --------------------------------------------------------------------------------
# Batch 61: inputs.shape=torch.Size([1, 4]), targets.shape=torch.Size([1, 4]), dtype=torch.int64
#   Sample 0:
#     input ids : [13, 357, 10915, 314]
#     target ids: [357, 10915, 314, 2138]
#     input text: '. (Though I'
#     target text: ' (Though I rather'
# --------------------------------------------------------------------------------
# Batch 62: inputs.shape=torch.Size([1, 4]), targets.shape=torch.Size([1, 4]), dtype=torch.int64
#   Sample 0:
#     input ids : [357, 10915, 314, 2138]
#     target ids: [10915, 314, 2138, 1807]
#     input text: ' (Though I rather'
#     target text: 'Though I rather thought'
# --------------------------------------------------------------------------------
# Batch 63: inputs.shape=torch.Size([1, 4]), targets.shape=torch.Size([1, 4]), dtype=torch.int64
#   Sample 0:
#     input ids : [10915, 314, 2138, 1807]
#     target ids: [314, 2138, 1807, 340]
#     input text: 'Though I rather thought'
#     target text: ' I rather thought it'
# --------------------------------------------------------------------------------
# Batch 64: inputs.shape=torch.Size([1, 4]), targets.shape=torch.Size([1, 4]), dtype=torch.int64
#   Sample 0:
#     input ids : [314, 2138, 1807, 340]
#     target ids: [2138, 1807, 340, 561]
#     input text: ' I rather thought it'
#     target text: ' rather thought it would'
# --------------------------------------------------------------------------------
# Batch 65: inputs.shape=torch.Size([1, 4]), targets.shape=torch.Size([1, 4]), dtype=torch.int64
#   Sample 0:
#     input ids : [2138, 1807, 340, 561]
#     target ids: [1807, 340, 561, 423]
#     input text: ' rather thought it would'
#     target text: ' thought it would have'
# --------------------------------------------------------------------------------
# Batch 66: inputs.shape=torch.Size([1, 4]), targets.shape=torch.Size([1, 4]), dtype=torch.int64
#   Sample 0:
#     input ids : [1807, 340, 561, 423]
#     target ids: [340, 561, 423, 587]
#     input text: ' thought it would have'
#     target text: ' it would have been'
# --------------------------------------------------------------------------------
# Batch 67: inputs.shape=torch.Size([1, 4]), targets.shape=torch.Size([1, 4]), dtype=torch.int64
#   Sample 0:
#     input ids : [340, 561, 423, 587]
#     target ids: [561, 423, 587, 10598]
#     input text: ' it would have been'
#     target text: ' would have been Rome'
# --------------------------------------------------------------------------------
# Batch 68: inputs.shape=torch.Size([1, 4]), targets.shape=torch.Size([1, 4]), dtype=torch.int64
#   Sample 0:
#     input ids : [561, 423, 587, 10598]
#     target ids: [423, 587, 10598, 393]
#     input text: ' would have been Rome'
#     target text: ' have been Rome or'
# --------------------------------------------------------------------------------
# Batch 69: inputs.shape=torch.Size([1, 4]), targets.shape=torch.Size([1, 4]), dtype=torch.int64
#   Sample 0:
#     input ids : [423, 587, 10598, 393]
#     target ids: [587, 10598, 393, 28537]
#     input text: ' have been Rome or'
#     target text: ' been Rome or Florence'
# --------------------------------------------------------------------------------
# Batch 70: inputs.shape=torch.Size([1, 4]), targets.shape=torch.Size([1, 4]), dtype=torch.int64
#   Sample 0:
#     input ids : [587, 10598, 393, 28537]
#     target ids: [10598, 393, 28537, 2014]
#     input text: ' been Rome or Florence'
#     target text: ' Rome or Florence.)'
# --------------------------------------------------------------------------------
# Batch 71: inputs.shape=torch.Size([1, 4]), targets.shape=torch.Size([1, 4]), dtype=torch.int64
#   Sample 0:
#     input ids : [10598, 393, 28537, 2014]
#     target ids: [393, 28537, 2014, 198]
#     input text: ' Rome or Florence.)'
#     target text: ' or Florence.)\n'
# --------------------------------------------------------------------------------
# Batch 72: inputs.shape=torch.Size([1, 4]), targets.shape=torch.Size([1, 4]), dtype=torch.int64
#   Sample 0:
#     input ids : [393, 28537, 2014, 198]
#     target ids: [28537, 2014, 198, 198]
#     input text: ' or Florence.)\n'
#     target text: ' Florence.)\n\n'
# --------------------------------------------------------------------------------
# Batch 73: inputs.shape=torch.Size([1, 4]), targets.shape=torch.Size([1, 4]), dtype=torch.int64
#   Sample 0:
#     input ids : [28537, 2014, 198, 198]
#     target ids: [2014, 198, 198, 1]
#     input text: ' Florence.)\n\n'
#     target text: '.)\n\n"'
# --------------------------------------------------------------------------------
# Batch 74: inputs.shape=torch.Size([1, 4]), targets.shape=torch.Size([1, 4]), dtype=torch.int64
#   Sample 0:
#     input ids : [2014, 198, 198, 1]
#     target ids: [198, 198, 1, 464]
#     input text: '.)\n\n"'
#     target text: '\n\n"The'
# --------------------------------------------------------------------------------
# Batch 75: inputs.shape=torch.Size([1, 4]), targets.shape=torch.Size([1, 4]), dtype=torch.int64
#   Sample 0:
#     input ids : [198, 198, 1, 464]
#     target ids: [198, 1, 464, 6001]
#     input text: '\n\n"The'
#     target text: '\n"The height'
# --------------------------------------------------------------------------------
# Batch 76: inputs.shape=torch.Size([1, 4]), targets.shape=torch.Size([1, 4]), dtype=torch.int64
#   Sample 0:
#     input ids : [198, 1, 464, 6001]
#     target ids: [1, 464, 6001, 286]
#     input text: '\n"The height'
#     target text: '"The height of'
# --------------------------------------------------------------------------------
# Batch 77: inputs.shape=torch.Size([1, 4]), targets.shape=torch.Size([1, 4]), dtype=torch.int64
#   Sample 0:
#     input ids : [1, 464, 6001, 286]
#     target ids: [464, 6001, 286, 465]
#     input text: '"The height of'
#     target text: 'The height of his'
# --------------------------------------------------------------------------------
# Batch 78: inputs.shape=torch.Size([1, 4]), targets.shape=torch.Size([1, 4]), dtype=torch.int64
#   Sample 0:
#     input ids : [464, 6001, 286, 465]
#     target ids: [6001, 286, 465, 13476]
#     input text: 'The height of his'
#     target text: ' height of his glory'
# --------------------------------------------------------------------------------
# Batch 79: inputs.shape=torch.Size([1, 4]), targets.shape=torch.Size([1, 4]), dtype=torch.int64
#   Sample 0:
#     input ids : [6001, 286, 465, 13476]
#     target ids: [286, 465, 13476, 1]
#     input text: ' height of his glory'
#     target text: ' of his glory"'
# --------------------------------------------------------------------------------
# Batch 80: inputs.shape=torch.Size([1, 4]), targets.shape=torch.Size([1, 4]), dtype=torch.int64
#   Sample 0:
#     input ids : [286, 465, 13476, 1]
#     target ids: [465, 13476, 1, 438]
#     input text: ' of his glory"'
#     target text: ' his glory"--'
# --------------------------------------------------------------------------------
# Batch 81: inputs.shape=torch.Size([1, 4]), targets.shape=torch.Size([1, 4]), dtype=torch.int64
#   Sample 0:
#     input ids : [465, 13476, 1, 438]
#     target ids: [13476, 1, 438, 5562]
#     input text: ' his glory"--'
#     target text: ' glory"--that'
# --------------------------------------------------------------------------------
# Batch 82: inputs.shape=torch.Size([1, 4]), targets.shape=torch.Size([1, 4]), dtype=torch.int64
#   Sample 0:
#     input ids : [13476, 1, 438, 5562]
#     target ids: [1, 438, 5562, 373]
#     input text: ' glory"--that'
#     target text: '"--that was'
# --------------------------------------------------------------------------------
# Batch 83: inputs.shape=torch.Size([1, 4]), targets.shape=torch.Size([1, 4]), dtype=torch.int64
#   Sample 0:
#     input ids : [1, 438, 5562, 373]
#     target ids: [438, 5562, 373, 644]
#     input text: '"--that was'
#     target text: '--that was what'
# --------------------------------------------------------------------------------
# Batch 84: inputs.shape=torch.Size([1, 4]), targets.shape=torch.Size([1, 4]), dtype=torch.int64
#   Sample 0:
#     input ids : [438, 5562, 373, 644]
#     target ids: [5562, 373, 644, 262]
#     input text: '--that was what'
#     target text: 'that was what the'
# --------------------------------------------------------------------------------
# Batch 85: inputs.shape=torch.Size([1, 4]), targets.shape=torch.Size([1, 4]), dtype=torch.int64
#   Sample 0:
#     input ids : [5562, 373, 644, 262]
#     target ids: [373, 644, 262, 1466]
#     input text: 'that was what the'
#     target text: ' was what the women'
# --------------------------------------------------------------------------------
# Batch 86: inputs.shape=torch.Size([1, 4]), targets.shape=torch.Size([1, 4]), dtype=torch.int64
#   Sample 0:
#     input ids : [373, 644, 262, 1466]
#     target ids: [644, 262, 1466, 1444]
#     input text: ' was what the women'
#     target text: ' what the women called'
# --------------------------------------------------------------------------------
# Batch 87: inputs.shape=torch.Size([1, 4]), targets.shape=torch.Size([1, 4]), dtype=torch.int64
#   Sample 0:
#     input ids : [644, 262, 1466, 1444]
#     target ids: [262, 1466, 1444, 340]
#     input text: ' what the women called'
#     target text: ' the women called it'
# --------------------------------------------------------------------------------
# Batch 88: inputs.shape=torch.Size([1, 4]), targets.shape=torch.Size([1, 4]), dtype=torch.int64
#   Sample 0:
#     input ids : [262, 1466, 1444, 340]
#     target ids: [1466, 1444, 340, 13]
#     input text: ' the women called it'
#     target text: ' women called it.'
# --------------------------------------------------------------------------------
# Batch 89: inputs.shape=torch.Size([1, 4]), targets.shape=torch.Size([1, 4]), dtype=torch.int64
#   Sample 0:
#     input ids : [1466, 1444, 340, 13]
#     target ids: [1444, 340, 13, 314]
#     input text: ' women called it.'
#     target text: ' called it. I'
# --------------------------------------------------------------------------------
# Batch 90: inputs.shape=torch.Size([1, 4]), targets.shape=torch.Size([1, 4]), dtype=torch.int64
#   Sample 0:
#     input ids : [1444, 340, 13, 314]
#     target ids: [340, 13, 314, 460]
#     input text: ' called it. I'
#     target text: ' it. I can'
# --------------------------------------------------------------------------------
# Batch 91: inputs.shape=torch.Size([1, 4]), targets.shape=torch.Size([1, 4]), dtype=torch.int64
#   Sample 0:
#     input ids : [340, 13, 314, 460]
#     target ids: [13, 314, 460, 3285]
#     input text: ' it. I can'
#     target text: '. I can hear'
# --------------------------------------------------------------------------------
# Batch 92: inputs.shape=torch.Size([1, 4]), targets.shape=torch.Size([1, 4]), dtype=torch.int64
#   Sample 0:
#     input ids : [13, 314, 460, 3285]
#     target ids: [314, 460, 3285, 9074]
#     input text: '. I can hear'
#     target text: ' I can hear Mrs'
# --------------------------------------------------------------------------------
# Batch 93: inputs.shape=torch.Size([1, 4]), targets.shape=torch.Size([1, 4]), dtype=torch.int64
#   Sample 0:
#     input ids : [314, 460, 3285, 9074]
#     target ids: [460, 3285, 9074, 13]
#     input text: ' I can hear Mrs'
#     target text: ' can hear Mrs.'
# --------------------------------------------------------------------------------
# Batch 94: inputs.shape=torch.Size([1, 4]), targets.shape=torch.Size([1, 4]), dtype=torch.int64
#   Sample 0:
#     input ids : [460, 3285, 9074, 13]
#     target ids: [3285, 9074, 13, 46606]
#     input text: ' can hear Mrs.'
#     target text: ' hear Mrs. Gideon'
# --------------------------------------------------------------------------------
# Batch 95: inputs.shape=torch.Size([1, 4]), targets.shape=torch.Size([1, 4]), dtype=torch.int64
#   Sample 0:
#     input ids : [3285, 9074, 13, 46606]
#     target ids: [9074, 13, 46606, 536]
#     input text: ' hear Mrs. Gideon'
#     target text: ' Mrs. Gideon Th'
# --------------------------------------------------------------------------------
# Batch 96: inputs.shape=torch.Size([1, 4]), targets.shape=torch.Size([1, 4]), dtype=torch.int64
#   Sample 0:
#     input ids : [9074, 13, 46606, 536]
#     target ids: [13, 46606, 536, 5469]
#     input text: ' Mrs. Gideon Th'
#     target text: '. Gideon Thwing'
# --------------------------------------------------------------------------------
# Batch 97: inputs.shape=torch.Size([1, 4]), targets.shape=torch.Size([1, 4]), dtype=torch.int64
#   Sample 0:
#     input ids : [13, 46606, 536, 5469]
#     target ids: [46606, 536, 5469, 438]
#     input text: '. Gideon Thwing'
#     target text: ' Gideon Thwing--'
# --------------------------------------------------------------------------------
# Batch 98: inputs.shape=torch.Size([1, 4]), targets.shape=torch.Size([1, 4]), dtype=torch.int64
#   Sample 0:
#     input ids : [46606, 536, 5469, 438]
#     target ids: [536, 5469, 438, 14363]
#     input text: ' Gideon Thwing--'
#     target text: ' Thwing--his'
# --------------------------------------------------------------------------------
# Batch 99: inputs.shape=torch.Size([1, 4]), targets.shape=torch.Size([1, 4]), dtype=torch.int64
#   Sample 0:
#     input ids : [536, 5469, 438, 14363]
#     target ids: [5469, 438, 14363, 938]
#     input text: ' Thwing--his'
#     target text: 'wing--his last'
# --------------------------------------------------------------------------------
# Batch 100: inputs.shape=torch.Size([1, 4]), targets.shape=torch.Size([1, 4]), dtype=torch.int64
#   Sample 0:
#     input ids : [5469, 438, 14363, 938]
#     target ids: [438, 14363, 938, 4842]
#     input text: 'wing--his last'
#     target text: '--his last Chicago'
# --------------------------------------------------------------------------------
# Batch 101: inputs.shape=torch.Size([1, 4]), targets.shape=torch.Size([1, 4]), dtype=torch.int64
#   Sample 0:
#     input ids : [438, 14363, 938, 4842]
#     target ids: [14363, 938, 4842, 1650]
#     input text: '--his last Chicago'
#     target text: 'his last Chicago sit'
# --------------------------------------------------------------------------------
# Batch 102: inputs.shape=torch.Size([1, 4]), targets.shape=torch.Size([1, 4]), dtype=torch.int64
#   Sample 0:
#     input ids : [14363, 938, 4842, 1650]
#     target ids: [938, 4842, 1650, 353]
#     input text: 'his last Chicago sit'
#     target text: ' last Chicago sitter'
# --------------------------------------------------------------------------------
# Batch 103: inputs.shape=torch.Size([1, 4]), targets.shape=torch.Size([1, 4]), dtype=torch.int64
#   Sample 0:
#     input ids : [938, 4842, 1650, 353]
#     target ids: [4842, 1650, 353, 438]
#     input text: ' last Chicago sitter'
#     target text: ' Chicago sitter--'
# --------------------------------------------------------------------------------
# Batch 104: inputs.shape=torch.Size([1, 4]), targets.shape=torch.Size([1, 4]), dtype=torch.int64
#   Sample 0:
#     input ids : [4842, 1650, 353, 438]
#     target ids: [1650, 353, 438, 2934]
#     input text: ' Chicago sitter--'
#     target text: ' sitter--de'
# --------------------------------------------------------------------------------
# Batch 105: inputs.shape=torch.Size([1, 4]), targets.shape=torch.Size([1, 4]), dtype=torch.int64
#   Sample 0:
#     input ids : [1650, 353, 438, 2934]
#     target ids: [353, 438, 2934, 489]
#     input text: ' sitter--de'
#     target text: 'ter--depl'
# --------------------------------------------------------------------------------
# Batch 106: inputs.shape=torch.Size([1, 4]), targets.shape=torch.Size([1, 4]), dtype=torch.int64
#   Sample 0:
#     input ids : [353, 438, 2934, 489]
#     target ids: [438, 2934, 489, 3255]
#     input text: 'ter--depl'
#     target text: '--deploring'
# --------------------------------------------------------------------------------
# Batch 107: inputs.shape=torch.Size([1, 4]), targets.shape=torch.Size([1, 4]), dtype=torch.int64
#   Sample 0:
#     input ids : [438, 2934, 489, 3255]
#     target ids: [2934, 489, 3255, 465]
#     input text: '--deploring'
#     target text: 'deploring his'
# --------------------------------------------------------------------------------
# Batch 108: inputs.shape=torch.Size([1, 4]), targets.shape=torch.Size([1, 4]), dtype=torch.int64
#   Sample 0:
#     input ids : [2934, 489, 3255, 465]
#     target ids: [489, 3255, 465, 48422]
#     input text: 'deploring his'
#     target text: 'ploring his unaccount'
# --------------------------------------------------------------------------------
# Batch 109: inputs.shape=torch.Size([1, 4]), targets.shape=torch.Size([1, 4]), dtype=torch.int64
#   Sample 0:
#     input ids : [489, 3255, 465, 48422]
#     target ids: [3255, 465, 48422, 540]
#     input text: 'ploring his unaccount'
#     target text: 'oring his unaccountable'
# --------------------------------------------------------------------------------
# Batch 110: inputs.shape=torch.Size([1, 4]), targets.shape=torch.Size([1, 4]), dtype=torch.int64
#   Sample 0:
#     input ids : [3255, 465, 48422, 540]
#     target ids: [465, 48422, 540, 450]
#     input text: 'oring his unaccountable'
#     target text: ' his unaccountable ab'
# --------------------------------------------------------------------------------
# Batch 111: inputs.shape=torch.Size([1, 4]), targets.shape=torch.Size([1, 4]), dtype=torch.int64
#   Sample 0:
#     input ids : [465, 48422, 540, 450]
#     target ids: [48422, 540, 450, 67]
#     input text: ' his unaccountable ab'
#     target text: ' unaccountable abd'
# --------------------------------------------------------------------------------
# Batch 112: inputs.shape=torch.Size([1, 4]), targets.shape=torch.Size([1, 4]), dtype=torch.int64
#   Sample 0:
#     input ids : [48422, 540, 450, 67]
#     target ids: [540, 450, 67, 3299]
#     input text: ' unaccountable abd'
#     target text: 'able abdication'
# --------------------------------------------------------------------------------
# Batch 113: inputs.shape=torch.Size([1, 4]), targets.shape=torch.Size([1, 4]), dtype=torch.int64
#   Sample 0:
#     input ids : [540, 450, 67, 3299]
#     target ids: [450, 67, 3299, 13]
#     input text: 'able abdication'
#     target text: ' abdication.'
# --------------------------------------------------------------------------------
# Batch 114: inputs.shape=torch.Size([1, 4]), targets.shape=torch.Size([1, 4]), dtype=torch.int64
#   Sample 0:
#     input ids : [450, 67, 3299, 13]
#     target ids: [67, 3299, 13, 366]
#     input text: ' abdication.'
#     target text: 'dication. "'
# --------------------------------------------------------------------------------
# Batch 115: inputs.shape=torch.Size([1, 4]), targets.shape=torch.Size([1, 4]), dtype=torch.int64
#   Sample 0:
#     input ids : [67, 3299, 13, 366]
#     target ids: [3299, 13, 366, 5189]
#     input text: 'dication. "'
#     target text: 'ication. "Of'
# --------------------------------------------------------------------------------
# Batch 116: inputs.shape=torch.Size([1, 4]), targets.shape=torch.Size([1, 4]), dtype=torch.int64
#   Sample 0:
#     input ids : [3299, 13, 366, 5189]
#     target ids: [13, 366, 5189, 1781]
#     input text: 'ication. "Of'
#     target text: '. "Of course'
# --------------------------------------------------------------------------------
# Batch 117: inputs.shape=torch.Size([1, 4]), targets.shape=torch.Size([1, 4]), dtype=torch.int64
#   Sample 0:
#     input ids : [13, 366, 5189, 1781]
#     target ids: [366, 5189, 1781, 340]
#     input text: '. "Of course'
#     target text: ' "Of course it'
# --------------------------------------------------------------------------------
# Batch 118: inputs.shape=torch.Size([1, 4]), targets.shape=torch.Size([1, 4]), dtype=torch.int64
#   Sample 0:
#     input ids : [366, 5189, 1781, 340]
#     target ids: [5189, 1781, 340, 338]
#     input text: ' "Of course it'
#     target text: "Of course it's"
# --------------------------------------------------------------------------------
# Batch 119: inputs.shape=torch.Size([1, 4]), targets.shape=torch.Size([1, 4]), dtype=torch.int64
#   Sample 0:
#     input ids : [5189, 1781, 340, 338]
#     target ids: [1781, 340, 338, 1016]
#     input text: "Of course it's"
#     target text: " course it's going"
# --------------------------------------------------------------------------------
# Batch 120: inputs.shape=torch.Size([1, 4]), targets.shape=torch.Size([1, 4]), dtype=torch.int64
#   Sample 0:
#     input ids : [1781, 340, 338, 1016]
#     target ids: [340, 338, 1016, 284]
#     input text: " course it's going"
#     target text: " it's going to"
# --------------------------------------------------------------------------------
# Batch 121: inputs.shape=torch.Size([1, 4]), targets.shape=torch.Size([1, 4]), dtype=torch.int64
#   Sample 0:
#     input ids : [340, 338, 1016, 284]
#     target ids: [338, 1016, 284, 3758]
#     input text: " it's going to"
#     target text: "'s going to send"
# --------------------------------------------------------------------------------
# Batch 122: inputs.shape=torch.Size([1, 4]), targets.shape=torch.Size([1, 4]), dtype=torch.int64
#   Sample 0:
#     input ids : [338, 1016, 284, 3758]
#     target ids: [1016, 284, 3758, 262]
#     input text: "'s going to send"
#     target text: ' going to send the'
# --------------------------------------------------------------------------------
# Batch 123: inputs.shape=torch.Size([1, 4]), targets.shape=torch.Size([1, 4]), dtype=torch.int64
#   Sample 0:
#     input ids : [1016, 284, 3758, 262]
#     target ids: [284, 3758, 262, 1988]
#     input text: ' going to send the'
#     target text: ' to send the value'
# --------------------------------------------------------------------------------
# Batch 124: inputs.shape=torch.Size([1, 4]), targets.shape=torch.Size([1, 4]), dtype=torch.int64
#   Sample 0:
#     input ids : [284, 3758, 262, 1988]
#     target ids: [3758, 262, 1988, 286]
#     input text: ' to send the value'
#     target text: ' send the value of'
# --------------------------------------------------------------------------------
# Batch 125: inputs.shape=torch.Size([1, 4]), targets.shape=torch.Size([1, 4]), dtype=torch.int64
#   Sample 0:
#     input ids : [3758, 262, 1988, 286]
#     target ids: [262, 1988, 286, 616]
#     input text: ' send the value of'
#     target text: ' the value of my'
# --------------------------------------------------------------------------------
# Batch 126: inputs.shape=torch.Size([1, 4]), targets.shape=torch.Size([1, 4]), dtype=torch.int64
#   Sample 0:
#     input ids : [262, 1988, 286, 616]
#     target ids: [1988, 286, 616, 4286]
#     input text: ' the value of my'
#     target text: ' value of my picture'
# --------------------------------------------------------------------------------
# Batch 127: inputs.shape=torch.Size([1, 4]), targets.shape=torch.Size([1, 4]), dtype=torch.int64
#   Sample 0:
#     input ids : [1988, 286, 616, 4286]
#     target ids: [286, 616, 4286, 705]
#     input text: ' value of my picture'
#     target text: " of my picture '"
# --------------------------------------------------------------------------------
# Batch 128: inputs.shape=torch.Size([1, 4]), targets.shape=torch.Size([1, 4]), dtype=torch.int64
#   Sample 0:
#     input ids : [286, 616, 4286, 705]
#     target ids: [616, 4286, 705, 1014]
#     input text: " of my picture '"
#     target text: " my picture 'way"
# --------------------------------------------------------------------------------
# Batch 129: inputs.shape=torch.Size([1, 4]), targets.shape=torch.Size([1, 4]), dtype=torch.int64
#   Sample 0:
#     input ids : [616, 4286, 705, 1014]
#     target ids: [4286, 705, 1014, 510]
#     input text: " my picture 'way"
#     target text: " picture 'way up"
# --------------------------------------------------------------------------------
# Batch 130: inputs.shape=torch.Size([1, 4]), targets.shape=torch.Size([1, 4]), dtype=torch.int64
#   Sample 0:
#     input ids : [4286, 705, 1014, 510]
#     target ids: [705, 1014, 510, 26]
#     input text: " picture 'way up"
#     target text: " 'way up;"
# --------------------------------------------------------------------------------
# Batch 131: inputs.shape=torch.Size([1, 4]), targets.shape=torch.Size([1, 4]), dtype=torch.int64
#   Sample 0:
#     input ids : [705, 1014, 510, 26]
#     target ids: [1014, 510, 26, 475]
#     input text: " 'way up;"
#     target text: 'way up; but'
# --------------------------------------------------------------------------------
# Batch 132: inputs.shape=torch.Size([1, 4]), targets.shape=torch.Size([1, 4]), dtype=torch.int64
#   Sample 0:
#     input ids : [1014, 510, 26, 475]
#     target ids: [510, 26, 475, 314]
#     input text: 'way up; but'
#     target text: ' up; but I'
# --------------------------------------------------------------------------------
# Batch 133: inputs.shape=torch.Size([1, 4]), targets.shape=torch.Size([1, 4]), dtype=torch.int64
#   Sample 0:
#     input ids : [510, 26, 475, 314]
#     target ids: [26, 475, 314, 836]
#     input text: ' up; but I'
#     target text: '; but I don'
# --------------------------------------------------------------------------------
# Batch 134: inputs.shape=torch.Size([1, 4]), targets.shape=torch.Size([1, 4]), dtype=torch.int64
#   Sample 0:
#     input ids : [26, 475, 314, 836]
#     target ids: [475, 314, 836, 470]
#     input text: '; but I don'
#     target text: " but I don't"
# --------------------------------------------------------------------------------
# Batch 135: inputs.shape=torch.Size([1, 4]), targets.shape=torch.Size([1, 4]), dtype=torch.int64
#   Sample 0:
#     input ids : [475, 314, 836, 470]
#     target ids: [314, 836, 470, 892]
#     input text: " but I don't"
#     target text: " I don't think"
# --------------------------------------------------------------------------------
# Batch 136: inputs.shape=torch.Size([1, 4]), targets.shape=torch.Size([1, 4]), dtype=torch.int64
#   Sample 0:
#     input ids : [314, 836, 470, 892]
#     target ids: [836, 470, 892, 286]
#     input text: " I don't think"
#     target text: " don't think of"
# --------------------------------------------------------------------------------
# Batch 137: inputs.shape=torch.Size([1, 4]), targets.shape=torch.Size([1, 4]), dtype=torch.int64
#   Sample 0:
#     input ids : [836, 470, 892, 286]
#     target ids: [470, 892, 286, 326]
#     input text: " don't think of"
#     target text: "'t think of that"
# --------------------------------------------------------------------------------
# Batch 138: inputs.shape=torch.Size([1, 4]), targets.shape=torch.Size([1, 4]), dtype=torch.int64
#   Sample 0:
#     input ids : [470, 892, 286, 326]
#     target ids: [892, 286, 326, 11]
#     input text: "'t think of that"
#     target text: ' think of that,'
# --------------------------------------------------------------------------------
# Batch 139: inputs.shape=torch.Size([1, 4]), targets.shape=torch.Size([1, 4]), dtype=torch.int64
#   Sample 0:
#     input ids : [892, 286, 326, 11]
#     target ids: [286, 326, 11, 1770]
#     input text: ' think of that,'
#     target text: ' of that, Mr'
# --------------------------------------------------------------------------------
# Batch 140: inputs.shape=torch.Size([1, 4]), targets.shape=torch.Size([1, 4]), dtype=torch.int64
#   Sample 0:
#     input ids : [286, 326, 11, 1770]
#     target ids: [326, 11, 1770, 13]
#     input text: ' of that, Mr'
#     target text: ' that, Mr.'
# --------------------------------------------------------------------------------
# Batch 141: inputs.shape=torch.Size([1, 4]), targets.shape=torch.Size([1, 4]), dtype=torch.int64
#   Sample 0:
#     input ids : [326, 11, 1770, 13]
#     target ids: [11, 1770, 13, 8759]
#     input text: ' that, Mr.'
#     target text: ', Mr. Rick'
# --------------------------------------------------------------------------------
# Batch 142: inputs.shape=torch.Size([1, 4]), targets.shape=torch.Size([1, 4]), dtype=torch.int64
#   Sample 0:
#     input ids : [11, 1770, 13, 8759]
#     target ids: [1770, 13, 8759, 2763]
# ...
#     input text: ' my shoulder with a'
#     target text: ' shoulder with a laugh'
# --------------------------------------------------------------------------------
# Batch 5094: inputs.shape=torch.Size([1, 4]), targets.shape=torch.Size([1, 4]), dtype=torch.int64
#   Sample 0:
#     input ids : [8163, 351, 257, 6487]
#     target ids: [351, 257, 6487, 13]
#     input text: ' shoulder with a laugh'
#     target text: ' with a laugh.'
# --------------------------------------------------------------------------------
# Batch 5095: inputs.shape=torch.Size([1, 4]), targets.shape=torch.Size([1, 4]), dtype=torch.int64
#   Sample 0:
#     input ids : [351, 257, 6487, 13]
#     target ids: [257, 6487, 13, 366]
#     input text: ' with a laugh.'
#     target text: ' a laugh. "'
# --------------------------------------------------------------------------------
# Batch 5096: inputs.shape=torch.Size([1, 4]), targets.shape=torch.Size([1, 4]), dtype=torch.int64
#   Sample 0:
#     input ids : [257, 6487, 13, 366]
#     target ids: [6487, 13, 366, 10049]
#     input text: ' a laugh. "'
#     target text: ' laugh. "Only'
# --------------------------------------------------------------------------------
# Batch 5097: inputs.shape=torch.Size([1, 4]), targets.shape=torch.Size([1, 4]), dtype=torch.int64
#   Sample 0:
#     input ids : [6487, 13, 366, 10049]
#     target ids: [13, 366, 10049, 262]
#     input text: ' laugh. "Only'
#     target text: '. "Only the'
# --------------------------------------------------------------------------------
# Batch 5098: inputs.shape=torch.Size([1, 4]), targets.shape=torch.Size([1, 4]), dtype=torch.int64
#   Sample 0:
#     input ids : [13, 366, 10049, 262]
#     target ids: [366, 10049, 262, 21296]
#     input text: '. "Only the'
#     target text: ' "Only the irony'
# --------------------------------------------------------------------------------
# Batch 5099: inputs.shape=torch.Size([1, 4]), targets.shape=torch.Size([1, 4]), dtype=torch.int64
#   Sample 0:
#     input ids : [366, 10049, 262, 21296]
#     target ids: [10049, 262, 21296, 286]
#     input text: ' "Only the irony'
#     target text: 'Only the irony of'
# --------------------------------------------------------------------------------
# Batch 5100: inputs.shape=torch.Size([1, 4]), targets.shape=torch.Size([1, 4]), dtype=torch.int64
#   Sample 0:
#     input ids : [10049, 262, 21296, 286]
#     target ids: [262, 21296, 286, 340]
#     input text: 'Only the irony of'
#     target text: ' the irony of it'
# --------------------------------------------------------------------------------
# Batch 5101: inputs.shape=torch.Size([1, 4]), targets.shape=torch.Size([1, 4]), dtype=torch.int64
#   Sample 0:
#     input ids : [262, 21296, 286, 340]
#     target ids: [21296, 286, 340, 318]
#     input text: ' the irony of it'
#     target text: ' irony of it is'
# --------------------------------------------------------------------------------
# Batch 5102: inputs.shape=torch.Size([1, 4]), targets.shape=torch.Size([1, 4]), dtype=torch.int64
#   Sample 0:
#     input ids : [21296, 286, 340, 318]
#     target ids: [286, 340, 318, 326]
#     input text: ' irony of it is'
#     target text: ' of it is that'
# --------------------------------------------------------------------------------
# Batch 5103: inputs.shape=torch.Size([1, 4]), targets.shape=torch.Size([1, 4]), dtype=torch.int64
#   Sample 0:
#     input ids : [286, 340, 318, 326]
#     target ids: [340, 318, 326, 314]
#     input text: ' of it is that'
#     target text: ' it is that I'
# --------------------------------------------------------------------------------
# Batch 5104: inputs.shape=torch.Size([1, 4]), targets.shape=torch.Size([1, 4]), dtype=torch.int64
#   Sample 0:
#     input ids : [340, 318, 326, 314]
#     target ids: [318, 326, 314, 4808]
#     input text: ' it is that I'
#     target text: ' is that I _'
# --------------------------------------------------------------------------------
# Batch 5105: inputs.shape=torch.Size([1, 4]), targets.shape=torch.Size([1, 4]), dtype=torch.int64
#   Sample 0:
#     input ids : [318, 326, 314, 4808]
#     target ids: [326, 314, 4808, 321]
#     input text: ' is that I _'
#     target text: ' that I _am'
# --------------------------------------------------------------------------------
# Batch 5106: inputs.shape=torch.Size([1, 4]), targets.shape=torch.Size([1, 4]), dtype=torch.int64
#   Sample 0:
#     input ids : [326, 314, 4808, 321]
#     target ids: [314, 4808, 321, 62]
#     input text: ' that I _am'
#     target text: ' I _am_'
# --------------------------------------------------------------------------------
# Batch 5107: inputs.shape=torch.Size([1, 4]), targets.shape=torch.Size([1, 4]), dtype=torch.int64
#   Sample 0:
#     input ids : [314, 4808, 321, 62]
#     target ids: [4808, 321, 62, 991]
#     input text: ' I _am_'
#     target text: ' _am_ still'
# --------------------------------------------------------------------------------
# Batch 5108: inputs.shape=torch.Size([1, 4]), targets.shape=torch.Size([1, 4]), dtype=torch.int64
#   Sample 0:
#     input ids : [4808, 321, 62, 991]
#     target ids: [321, 62, 991, 12036]
#     input text: ' _am_ still'
#     target text: 'am_ still painting'
# --------------------------------------------------------------------------------
# Batch 5109: inputs.shape=torch.Size([1, 4]), targets.shape=torch.Size([1, 4]), dtype=torch.int64
#   Sample 0:
#     input ids : [321, 62, 991, 12036]
#     target ids: [62, 991, 12036, 438]
#     input text: 'am_ still painting'
#     target text: '_ still painting--'
# --------------------------------------------------------------------------------
# Batch 5110: inputs.shape=torch.Size([1, 4]), targets.shape=torch.Size([1, 4]), dtype=torch.int64
#   Sample 0:
#     input ids : [62, 991, 12036, 438]
#     target ids: [991, 12036, 438, 20777]
#     input text: '_ still painting--'
#     target text: ' still painting--since'
# --------------------------------------------------------------------------------
# Batch 5111: inputs.shape=torch.Size([1, 4]), targets.shape=torch.Size([1, 4]), dtype=torch.int64
#   Sample 0:
#     input ids : [991, 12036, 438, 20777]
#     target ids: [12036, 438, 20777, 41379]
#     input text: ' still painting--since'
#     target text: ' painting--since Grind'
# --------------------------------------------------------------------------------
# Batch 5112: inputs.shape=torch.Size([1, 4]), targets.shape=torch.Size([1, 4]), dtype=torch.int64
#   Sample 0:
#     input ids : [12036, 438, 20777, 41379]
#     target ids: [438, 20777, 41379, 293]
#     input text: ' painting--since Grind'
#     target text: '--since Grindle'
# --------------------------------------------------------------------------------
# Batch 5113: inputs.shape=torch.Size([1, 4]), targets.shape=torch.Size([1, 4]), dtype=torch.int64
#   Sample 0:
#     input ids : [438, 20777, 41379, 293]
#     target ids: [20777, 41379, 293, 338]
#     input text: '--since Grindle'
#     target text: "since Grindle's"
# --------------------------------------------------------------------------------
# Batch 5114: inputs.shape=torch.Size([1, 4]), targets.shape=torch.Size([1, 4]), dtype=torch.int64
#   Sample 0:
#     input ids : [20777, 41379, 293, 338]
#     target ids: [41379, 293, 338, 1804]
#     input text: "since Grindle's"
#     target text: " Grindle's doing"
# --------------------------------------------------------------------------------
# Batch 5115: inputs.shape=torch.Size([1, 4]), targets.shape=torch.Size([1, 4]), dtype=torch.int64
#   Sample 0:
#     input ids : [41379, 293, 338, 1804]
#     target ids: [293, 338, 1804, 340]
#     input text: " Grindle's doing"
#     target text: "le's doing it"
# --------------------------------------------------------------------------------
# Batch 5116: inputs.shape=torch.Size([1, 4]), targets.shape=torch.Size([1, 4]), dtype=torch.int64
#   Sample 0:
#     input ids : [293, 338, 1804, 340]
#     target ids: [338, 1804, 340, 329]
#     input text: "le's doing it"
#     target text: "'s doing it for"
# --------------------------------------------------------------------------------
# Batch 5117: inputs.shape=torch.Size([1, 4]), targets.shape=torch.Size([1, 4]), dtype=torch.int64
#   Sample 0:
#     input ids : [338, 1804, 340, 329]
#     target ids: [1804, 340, 329, 502]
#     input text: "'s doing it for"
#     target text: ' doing it for me'
# --------------------------------------------------------------------------------
# Batch 5118: inputs.shape=torch.Size([1, 4]), targets.shape=torch.Size([1, 4]), dtype=torch.int64
#   Sample 0:
#     input ids : [1804, 340, 329, 502]
#     target ids: [340, 329, 502, 0]
#     input text: ' doing it for me'
#     target text: ' it for me!'
# --------------------------------------------------------------------------------
# Batch 5119: inputs.shape=torch.Size([1, 4]), targets.shape=torch.Size([1, 4]), dtype=torch.int64
#   Sample 0:
#     input ids : [340, 329, 502, 0]
#     target ids: [329, 502, 0, 383]
#     input text: ' it for me!'
#     target text: ' for me! The'
# --------------------------------------------------------------------------------
# Batch 5120: inputs.shape=torch.Size([1, 4]), targets.shape=torch.Size([1, 4]), dtype=torch.int64
#   Sample 0:
#     input ids : [329, 502, 0, 383]
#     target ids: [502, 0, 383, 520]
#     input text: ' for me! The'
#     target text: ' me! The St'
# --------------------------------------------------------------------------------
# Batch 5121: inputs.shape=torch.Size([1, 4]), targets.shape=torch.Size([1, 4]), dtype=torch.int64
#   Sample 0:
#     input ids : [502, 0, 383, 520]
#     target ids: [0, 383, 520, 5493]
#     input text: ' me! The St'
#     target text: '! The Stroud'
# --------------------------------------------------------------------------------
# Batch 5122: inputs.shape=torch.Size([1, 4]), targets.shape=torch.Size([1, 4]), dtype=torch.int64
#   Sample 0:
#     input ids : [0, 383, 520, 5493]
#     target ids: [383, 520, 5493, 82]
#     input text: '! The Stroud'
#     target text: ' The Strouds'
# --------------------------------------------------------------------------------
# Batch 5123: inputs.shape=torch.Size([1, 4]), targets.shape=torch.Size([1, 4]), dtype=torch.int64
#   Sample 0:
#     input ids : [383, 520, 5493, 82]
#     target ids: [520, 5493, 82, 1302]
#     input text: ' The Strouds'
#     target text: ' Strouds stand'
# --------------------------------------------------------------------------------
# Batch 5124: inputs.shape=torch.Size([1, 4]), targets.shape=torch.Size([1, 4]), dtype=torch.int64
#   Sample 0:
#     input ids : [520, 5493, 82, 1302]
#     target ids: [5493, 82, 1302, 3436]
#     input text: ' Strouds stand'
#     target text: 'rouds stand alone'
# --------------------------------------------------------------------------------
# Batch 5125: inputs.shape=torch.Size([1, 4]), targets.shape=torch.Size([1, 4]), dtype=torch.int64
#   Sample 0:
#     input ids : [5493, 82, 1302, 3436]
#     target ids: [82, 1302, 3436, 11]
#     input text: 'rouds stand alone'
#     target text: 's stand alone,'
# --------------------------------------------------------------------------------
# Batch 5126: inputs.shape=torch.Size([1, 4]), targets.shape=torch.Size([1, 4]), dtype=torch.int64
#   Sample 0:
#     input ids : [82, 1302, 3436, 11]
#     target ids: [1302, 3436, 11, 290]
#     input text: 's stand alone,'
#     target text: ' stand alone, and'
# --------------------------------------------------------------------------------
# Batch 5127: inputs.shape=torch.Size([1, 4]), targets.shape=torch.Size([1, 4]), dtype=torch.int64
#   Sample 0:
#     input ids : [1302, 3436, 11, 290]
#     target ids: [3436, 11, 290, 1645]
#     input text: ' stand alone, and'
#     target text: ' alone, and happen'
# --------------------------------------------------------------------------------
# Batch 5128: inputs.shape=torch.Size([1, 4]), targets.shape=torch.Size([1, 4]), dtype=torch.int64
#   Sample 0:
#     input ids : [3436, 11, 290, 1645]
#     target ids: [11, 290, 1645, 1752]
#     input text: ' alone, and happen'
#     target text: ', and happen once'
# --------------------------------------------------------------------------------
# Batch 5129: inputs.shape=torch.Size([1, 4]), targets.shape=torch.Size([1, 4]), dtype=torch.int64
#   Sample 0:
#     input ids : [11, 290, 1645, 1752]
#     target ids: [290, 1645, 1752, 438]
#     input text: ', and happen once'
#     target text: ' and happen once--'
# --------------------------------------------------------------------------------
# Batch 5130: inputs.shape=torch.Size([1, 4]), targets.shape=torch.Size([1, 4]), dtype=torch.int64
#   Sample 0:
#     input ids : [290, 1645, 1752, 438]
#     target ids: [1645, 1752, 438, 4360]
#     input text: ' and happen once--'
#     target text: ' happen once--but'
# --------------------------------------------------------------------------------
# Batch 5131: inputs.shape=torch.Size([1, 4]), targets.shape=torch.Size([1, 4]), dtype=torch.int64
#   Sample 0:
#     input ids : [1645, 1752, 438, 4360]
#     target ids: [1752, 438, 4360, 612]
#     input text: ' happen once--but'
#     target text: ' once--but there'
# --------------------------------------------------------------------------------
# Batch 5132: inputs.shape=torch.Size([1, 4]), targets.shape=torch.Size([1, 4]), dtype=torch.int64
#   Sample 0:
#     input ids : [1752, 438, 4360, 612]
#     target ids: [438, 4360, 612, 338]
#     input text: ' once--but there'
#     target text: "--but there's"
# --------------------------------------------------------------------------------
# Batch 5133: inputs.shape=torch.Size([1, 4]), targets.shape=torch.Size([1, 4]), dtype=torch.int64
#   Sample 0:
#     input ids : [438, 4360, 612, 338]
#     target ids: [4360, 612, 338, 645]
#     input text: "--but there's"
#     target text: "but there's no"
# --------------------------------------------------------------------------------
# Batch 5134: inputs.shape=torch.Size([1, 4]), targets.shape=torch.Size([1, 4]), dtype=torch.int64
#   Sample 0:
#     input ids : [4360, 612, 338, 645]
#     target ids: [612, 338, 645, 42393]
#     input text: "but there's no"
#     target text: " there's no extermin"
# --------------------------------------------------------------------------------
# Batch 5135: inputs.shape=torch.Size([1, 4]), targets.shape=torch.Size([1, 4]), dtype=torch.int64
#   Sample 0:
#     input ids : [612, 338, 645, 42393]
#     target ids: [338, 645, 42393, 803]
#     input text: " there's no extermin"
#     target text: "'s no exterminating"
# --------------------------------------------------------------------------------
# Batch 5136: inputs.shape=torch.Size([1, 4]), targets.shape=torch.Size([1, 4]), dtype=torch.int64
#   Sample 0:
#     input ids : [338, 645, 42393, 803]
#     target ids: [645, 42393, 803, 674]
#     input text: "'s no exterminating"
#     target text: ' no exterminating our'
# --------------------------------------------------------------------------------
# Batch 5137: inputs.shape=torch.Size([1, 4]), targets.shape=torch.Size([1, 4]), dtype=torch.int64
#   Sample 0:
#     input ids : [645, 42393, 803, 674]
#     target ids: [42393, 803, 674, 1611]
#     input text: ' no exterminating our'
#     target text: ' exterminating our kind'
# --------------------------------------------------------------------------------
# Batch 5138: inputs.shape=torch.Size([1, 4]), targets.shape=torch.Size([1, 4]), dtype=torch.int64
#   Sample 0:
#     input ids : [42393, 803, 674, 1611]
#     target ids: [803, 674, 1611, 286]
#     input text: ' exterminating our kind'
#     target text: 'ating our kind of'
# --------------------------------------------------------------------------------
# Batch 5139: inputs.shape=torch.Size([1, 4]), targets.shape=torch.Size([1, 4]), dtype=torch.int64
#   Sample 0:
#     input ids : [803, 674, 1611, 286]
#     target ids: [674, 1611, 286, 1242]
#     input text: 'ating our kind of'
#     target text: ' our kind of art'
# --------------------------------------------------------------------------------
# Batch 5140: inputs.shape=torch.Size([1, 4]), targets.shape=torch.Size([1, 4]), dtype=torch.int64
#   Sample 0:
#     input ids : [674, 1611, 286, 1242]
#     target ids: [1611, 286, 1242, 526]
#     input text: ' our kind of art'
#     target text: ' kind of art."'
# --------------------------------------------------------------------------------
